# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 22.7 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/For_object_detection/dataset/data.yaml epochs=100 plots=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 124MB/s]
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/For_object_detection/dataset/data.yaml
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/For_object_detection/dataset/val/labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.19it/s]
#                    all         60         76      0.966      0.885      0.935      0.731
#               Airplane         10         10          1      0.995      0.995      0.829
#                    Car         12         14      0.941      0.857      0.856      0.765
#                 Person         18         18          1      0.879       0.92      0.684
#                  Horse          9          9          1      0.821      0.995      0.808
#             Motorcycle         12         13      0.978      0.923      0.927      0.621
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/For_object_detection/dataset/test/images
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/31 /content/drive/MyDrive/For_object_detection/dataset/test/images/Airplane_15.jpg: 448x640 1 Airplane, 33.1ms
# image 2/31 /content/drive/MyDrive/For_object_detection/dataset/test/images/Airplane_23.jpg: 448x640 1 Airplane, 8.5ms
# image 3/31 /content/drive/MyDrive/For_object_detection/dataset/test/images/Airplane_25.jpg: 288x640 1 Airplane, 55.9ms
# image 4/31 /content/drive/MyDrive/For_object_detection/dataset/test/images/Airplane_3.jpg: 448x640 1 Airplane, 9.0ms
# image 5/31 /content/drive/MyDrive/For_object_detection/dataset/test/images/Airplane_31.jpg: 384x640 1 Airplane, 55.1ms
# image 6/31 /content/drive/MyDrive/For_object_detection/dataset/test/images/Airplane_37.jpg: 480x640 1 Airplane, 32.9ms
# ...

# %%
from PIL import Image

# %%
im= Image.open('/content/runs/detect/train/confusion_matrix.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>
